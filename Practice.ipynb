# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import seaborn as sns 
import matplotlib.pyplot as plt
data= pd.read_csv("linear_regression_1000_rows.csv")
data.head(3)
# Out:
#            X           Y
# 0  37.454012  117.362036
# 1  95.071431  290.214292
# 2  73.199394  224.598183

# %%
data.isnull().sum()
# Out:
# X    0
# Y    0
# dtype: int64

# %%
X=data[['X']]
y=data[['Y']]
X.head()
# Out:
#            X
# 0  37.454012
# 1  95.071431
# 2  73.199394
# 3  59.865848
# 4  15.601864

# %%
y.head()
# Out:
#             Y
# 0  117.362036
# 1  290.214292
# 2  224.598183
# 3  184.597545
# 4   51.805592

# %%
x_train,x_test,y_train,y_test= train_test_split(X,y,test_size=0.2)
x_train.shape
# Out:
# (800, 1)

# %%
le= LinearRegression()

# %%
le.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
le.predict([[90]])[0][0]
# Out:
# C:\Users\HII\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 275.0

# %%
y_pred= le.predict(x_test)
# Out:
# 180.86894960503918

# %%
sns.scatterplot(x='X',y="Y",data=data)
plt.show()

# %%
sns.heatmap(data=data.corr(),annot=True)
plt.show()

# %%
le.score(x_test,y_test)
# Out:
# 1.0
