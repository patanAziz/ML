# %%
import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt
data=pd.read_csv('messy_dataset.csv')
data.head(3)
data_income=data['Income']
data_income
# Out:
# 0        46939.23
# 1        35141.34
# 2        52011.45
# 3        55148.20
# 4        55930.32
#            ...
# 10195    47632.50
# 10196    46396.79
# 10197    57176.04
# 10198    41452.33
# 10199    55950.68
# Name: Income, Length: 10200, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10200 entries, 0 to 10199
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10200 non-null  int64
#  1   Name        10200 non-null  object
#  2   Age         9693 non-null   float64
#  3   Gender      9697 non-null   object
#  4   Income      9689 non-null   float64
#  5   Department  10200 non-null  object
#  6   JoinDate    10200 non-null  object
#  7   Rating      10200 non-null  float64
#  8   Remarks     7717 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 717.3+ KB

# %%
data.shape
# Out:
# (10200, 9)

# %%
null_percentage=(data.isnull().sum().sum())/(data.shape[0]*data.shape[1])*100
null_percentage
# Out:
# 4.3616557734204795

# %%
data.isnull().sum()
# Out:
# ID               0
# Name             0
# Age            507
# Gender         503
# Income         511
# Department       0
# JoinDate         0
# Rating           0
# Remarks       2483
# dtype: int64

# %%
data.describe()
# Out:
#                  ID          Age         Income        Rating
# count  10200.000000  9693.000000    9689.000000  10200.000000
# mean    5000.929412    29.519034   50832.932713      3.019392
# std     2886.537976     8.076104   23545.700771      1.156164
# min        1.000000    -2.000000   -6715.390000      1.000000
# 25%     2500.750000    24.000000   39892.070000      2.000000
# 50%     5003.500000    30.000000   50033.400000      3.000000
# 75%     7501.250000    35.000000   60470.150000      4.000000
# max    10000.000000    60.000000  845612.700000      5.000000

# %%
data['new_Age']=data['Age'].fillna(data['Age'].mode()[0])

# %%
data.head()
# Out:
#    ID     Name   Age  Gender    Income Department    JoinDate  Rating  Remarks
# 0   1    David  23.0       1  46939.23  Marketing  2020-05-03     4.0        2
# 1   2      Eva  26.0       2  35141.34  Marketing  2020-10-07     3.3        2
# 2   3  Charlie  49.0       2  52011.45      Sales  2010-10-23     3.5        2
# 3   4      Eva  23.0       0  55148.20         HR  2018-04-06     1.6        0
# 4   5      Eva  29.0       0  55930.32         HR  2018-11-26     1.6        3

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
re=LabelEncoder()

data['Gender']=le.fit_transform(data['Gender'])
data['Remarks']=re.fit_transform(data['Remarks'])
# Out:
# C:\Users\HII\AppData\Local\Temp\ipykernel_17168\615216137.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Gender']=le.fit_transform(data['Gender'])
# C:\Users\HII\AppData\Local\Temp\ipykernel_17168\615216137.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Remarks']=re.fit_transform(data['Remarks'])

# %%
data
# Out:
#          ID     Name   Age  Gender    Income Department    JoinDate  Rating  \
# 0         1    David  23.0       1  46939.23  Marketing  2020-05-03     4.0
# 1         2      Eva  26.0       2  35141.34  Marketing  2020-10-07     3.3
# 2         3  Charlie  49.0       2  52011.45      Sales  2010-10-23     3.5
# 3         4      Eva  23.0       0  55148.20         HR  2018-04-06     1.6
# 4         5      Eva  29.0       0  55930.32         HR  2018-11-26     1.6
# ...     ...      ...   ...     ...       ...        ...         ...     ...
# 9995   9996      Bob  34.0       2  52767.86         HR  2013-04-07     3.4
# 9996   9997  Charlie  14.0       2  55972.96         HR  2014-09-25     1.8
# 9997   9998      Bob  25.0       2  47913.72         HR  2018-04-21     3.7
# 9998   9999    David  10.0       1  62277.32  Marketing  2015-09-09     4.7
# 9999  10000  Charlie  43.0       1  48433.09      Sales  2013-03-16     2.8
#
#       Remarks
# 0           2
# 1           2
# ...

# %%
data.head()
# Out:
#    ID     Name   Age  Gender    Income Department    JoinDate  Rating  Remarks
# 0   1    David  23.0       1  46939.23  Marketing  2020-05-03     4.0        2
# 1   2      Eva  26.0       2  35141.34  Marketing  2020-10-07     3.3        2
# 2   3  Charlie  49.0       2  52011.45      Sales  2010-10-23     3.5        2
# 3   4      Eva  23.0       0  55148.20         HR  2018-04-06     1.6        0
# 4   5      Eva  29.0       0  55930.32         HR  2018-11-26     1.6        3

# %%
data.isnull().sum()
# Out:
# ID              0
# Name            0
# Age           507
# Gender          0
# Income          0
# Department      0
# JoinDate        0
# Rating          0
# Remarks         0
# dtype: int64

# %%
data.head(5)
# Out:
#    ID     Name   Age  Gender    Income Department    JoinDate  Rating  Remarks
# 0   1    David  23.0       1  46939.23  Marketing  2020-05-03     4.0        2
# 1   2      Eva  26.0       2  35141.34  Marketing  2020-10-07     3.3        2
# 2   3  Charlie  49.0       2  52011.45      Sales  2010-10-23     3.5        2
# 3   4      Eva  23.0       0  55148.20         HR  2018-04-06     1.6        0
# 4   5      Eva  29.0       0  55930.32         HR  2018-11-26     1.6        3

# %%
data['Income'].isnull().sum()
data
# Out:
#          ID     Name   Age  Gender    Income Department    JoinDate  Rating  \
# 0         1    David  23.0       1  46939.23  Marketing  2020-05-03     4.0
# 1         2      Eva  26.0       2  35141.34  Marketing  2020-10-07     3.3
# 2         3  Charlie  49.0       2  52011.45      Sales  2010-10-23     3.5
# 3         4      Eva  23.0       0  55148.20         HR  2018-04-06     1.6
# 4         5      Eva  29.0       0  55930.32         HR  2018-11-26     1.6
# ...     ...      ...   ...     ...       ...        ...         ...     ...
# 9995   9996      Bob  34.0       2  52767.86         HR  2013-04-07     3.4
# 9996   9997  Charlie  14.0       2  55972.96         HR  2014-09-25     1.8
# 9997   9998      Bob  25.0       2  47913.72         HR  2018-04-21     3.7
# 9998   9999    David  10.0       1  62277.32  Marketing  2015-09-09     4.7
# 9999  10000  Charlie  43.0       1  48433.09      Sales  2013-03-16     2.8
#
#       Remarks
# 0           2
# 1           2
# ...

# %%
data['Income']=data['Income'].fillna(data['Income'].mean())
data['Income'].isnull().sum()
# Out:
# 0

# %%
data
# Out:
#          ID     Name   Age  Gender    Income Department    JoinDate  Rating  \
# 0         1    David  23.0       1  46939.23  Marketing  2020-05-03     4.0
# 1         2      Eva  26.0       2  35141.34  Marketing  2020-10-07     3.3
# 2         3  Charlie  49.0       2  52011.45      Sales  2010-10-23     3.5
# 3         4      Eva  23.0       0  55148.20         HR  2018-04-06     1.6
# 4         5      Eva  29.0       0  55930.32         HR  2018-11-26     1.6
# ...     ...      ...   ...     ...       ...        ...         ...     ...
# 9995   9996      Bob  34.0       2  52767.86         HR  2013-04-07     3.4
# 9996   9997  Charlie  14.0       2  55972.96         HR  2014-09-25     1.8
# 9997   9998      Bob  25.0       2  47913.72         HR  2018-04-21     3.7
# 9998   9999    David  10.0       1  62277.32  Marketing  2015-09-09     4.7
# 9999  10000  Charlie  43.0       1  48433.09      Sales  2013-03-16     2.8
#
#       Remarks
# 0           2
# 1           2
# ...

# %%
# Allways remember to fill null values before handling outliers
# How to detect outlier
#     --> By using boxplot 
plt.figure(figsize=(8,4))
sns.boxplot(x='Income', data=data)
plt.show()

# %%
#     --> By using distplot

plt.figure(figsize=(8,4))
sns.distplot(data['Income'])
plt.show()
# data['Income']
data.head()
# Out:
# C:\Users\HII\AppData\Local\Temp\ipykernel_17168\1865104071.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Income'])
#    ID     Name   Age  Gender    Income Department    JoinDate  Rating  Remarks
# 0   1    David  23.0       1  46939.23  Marketing  2020-05-03     4.0        2
# 1   2      Eva  26.0       2  35141.34  Marketing  2020-10-07     3.3        2
# 2   3  Charlie  49.0       2  52011.45      Sales  2010-10-23     3.5        2
# 3   4      Eva  23.0       0  55148.20         HR  2018-04-06     1.6        0
# 4   5      Eva  29.0       0  55930.32         HR  2018-11-26     1.6        3

# %%
data['Income'].isnull().sum()
# Out:
# 0

# %%
I1=data['Income'].quantile(0.25)
I3=data['Income'].quantile(0.75)

IQR=I3-I1

min_range=I1-(1.5*IQR)
max_range=I3+(1.5*IQR)
min_range,max_range
# Out:
# (11517.494999999999, 88802.715)

# %%
data['Income']=(data['Income']<=max_range)
data['Income'].all()
# Out:
# True

# %%
data['Income']=data_income
data.head()
# Out:
# C:\Users\HII\AppData\Local\Temp\ipykernel_17168\2721793639.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Income']=data_income
#    ID     Name   Age  Gender    Income Department    JoinDate  Rating  Remarks
# 0   1    David  23.0       1  46939.23  Marketing  2020-05-03     4.0        2
# 1   2      Eva  26.0       2  35141.34  Marketing  2020-10-07     3.3        2
# 2   3  Charlie  49.0       2  52011.45      Sales  2010-10-23     3.5        2
# 3   4      Eva  23.0       0  55148.20         HR  2018-04-06     1.6        0
# 4   5      Eva  29.0       0  55930.32         HR  2018-11-26     1.6        3

# %%
data=data.drop_duplicates()
data.shape
# Out:
# (10000, 9)

# %%
data.head()
# Out:
#    ID     Name   Age  Gender    Income Department    JoinDate  Rating  Remarks
# 0   1    David  23.0       1  46939.23  Marketing  2020-05-03     4.0        2
# 1   2      Eva  26.0       2  35141.34  Marketing  2020-10-07     3.3        2
# 2   3  Charlie  49.0       2  52011.45      Sales  2010-10-23     3.5        2
# 3   4      Eva  23.0       0  55148.20         HR  2018-04-06     1.6        0
# 4   5      Eva  29.0       0  55930.32         HR  2018-11-26     1.6        3

# %%
data.isnull().sum()
# Out:
# ID              0
# Name            0
# Age           500
# Gender          0
# Income        500
# Department      0
# JoinDate        0
# Rating          0
# Remarks         0
# dtype: int64

# %%
data.drop('Age',axis=1)
# Out:
#          ID     Name  Gender    Income Department    JoinDate  Rating  Remarks
# 0         1    David       1  46939.23  Marketing  2020-05-03     4.0        2
# 1         2      Eva       2  35141.34  Marketing  2020-10-07     3.3        2
# 2         3  Charlie       2  52011.45      Sales  2010-10-23     3.5        2
# 3         4      Eva       0  55148.20         HR  2018-04-06     1.6        0
# 4         5      Eva       0  55930.32         HR  2018-11-26     1.6        3
# ...     ...      ...     ...       ...        ...         ...     ...      ...
# 9995   9996      Bob       2  52767.86         HR  2013-04-07     3.4        0
# 9996   9997  Charlie       2  55972.96         HR  2014-09-25     1.8        2
# 9997   9998      Bob       2  47913.72         HR  2018-04-21     3.7        4
# 9998   9999    David       1  62277.32  Marketing  2015-09-09     4.7        2
# 9999  10000  Charlie       1  48433.09      Sales  2013-03-16     2.8        0
#
# ...
